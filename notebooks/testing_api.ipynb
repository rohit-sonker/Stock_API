# %%
# !pip install nsetools

# %%
from nsetools import Nse
from pprint import pprint

# %%
nse = Nse()
print(nse)
# Out:
# Driver Class for National Stock Exchange (NSE)

# %%
q = nse.get_quote('infy')
pprint(q)
# Out:
# {'adhocMargin': None,
#  'applicableMargin': 15.9,
#  'averagePrice': 1406.43,
#  'basePrice': None,
#  'bcEndDate': None,
#  'bcStartDate': None,
#  'buyPrice1': 1405.05,
#  'buyPrice2': None,
#  'buyPrice3': None,
#  'buyPrice4': None,
#  'buyPrice5': None,
#  'buyQuantity1': 8668.0,
#  'buyQuantity2': None,
#  'buyQuantity3': None,
#  'buyQuantity4': None,
#  'buyQuantity5': None,
#  'change': 5.45,
#  'closePrice': 1405.05,
#  'cm_adj_high_dt': '12-APR-21',
#  'cm_adj_low_dt': '29-MAY-20',
#  'cm_ffm': 504622.92,
#  'companyName': 'Infosys Limited',
#  'css_status_desc': 'Listed',
#  'dayHigh': 1414.0,
#  'dayLow': 1396.1,
#  'deliveryQuantity': 2093923.0,
#  'deliveryToTradedQuantity': 49.14,
#  'exDate': '31-MAY-21',
#  'extremeLossMargin': 3.5,
#  'faceValue': 5.0,
#  'high52': 1477.55,
#  'indexVar': None,
#  'isExDateFlag': False,
#  'isinCode': 'INE009A01021',
#  'lastPrice': 1407.7,
#  'low52': 674.95,
#  'marketType': 'N',
#  'ndEndDate': None,
#  'ndStartDate': None,
# ...

# %%
import urllib.request

# %%
response = urllib.request("https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol=RELIANCE.BSE&outputsize=full&apikey=demo")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-b6246fdc2978> in <module>
# ----> 1 response = urllib.request("https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol=RELIANCE.BSE&outputsize=full&apikey=demo")
#
# TypeError: 'module' object is not callable

# %%
import requests
import json
import pandas as pd
import io

# %%
resp = requests.get("https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol=INFY.BSE&outputsize=full&datatype=json&apikey=9X8ZHYEYSV88S4T6")
x = resp.json()
x
# Out:
# {'Meta Data': {'1. Information': 'Daily Time Series with Splits and Dividend Events',
#   '2. Symbol': 'INFY.BSE',
#   '3. Last Refreshed': '2021-05-28',
#   '4. Output Size': 'Full size',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2021-05-28': {'1. open': '1411.85',
#    '2. high': '1414.0',
#    '3. low': '1396.35',
#    '4. close': '1404.8',
#    '5. adjusted close': '1404.8',
#    '6. volume': '418799',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2021-05-27': {'1. open': '1404.8',
#    '2. high': '1415.5',
#    '3. low': '1391.6',
#    '4. close': '1404.65',
#    '5. adjusted close': '1404.65',
#    '6. volume': '1353941',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2021-05-26': {'1. open': '1369.4',
#    '2. high': '1400.0',
#    '3. low': '1362.0',
#    '4. close': '1397.35',
#    '5. adjusted close': '1397.35',
#    '6. volume': '505592',
#    '7. dividend amount': '0.0000',
# ...

# %%
resp = requests.get("https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol=INFY.BSE&outputsize=full&datatype=csv&apikey=<enter>")

# %%
resp.content
# Out:
# b'timestamp,open,high,low,close,adjusted_close,volume,dividend_amount,split_coefficient\r\n2021-05-28,1411.85,1414.0,1396.35,1404.8,1404.8,418799,0.0000,1.0\r\n2021-05-27,1404.8,1415.5,1391.6,1404.65,1404.65,1353941,0.0000,1.0\r\n2021-05-26,1369.4,1400.0,1362.0,1397.35,1397.35,505592,0.0000,1.0\r\n2021-05-25,1353.0,1367.5,1353.0,1361.9,1361.9,420760,0.0000,1.0\r\n2021-05-24,1358.0,1362.15,1345.25,1348.15,1348.15,1066338,0.0000,1.0\r\n2021-05-21,1349.0,1357.0,1346.1,1354.7,1354.7,480568,0.0000,1.0\r\n2021-05-20,1345.0,1350.0,1335.4,1339.45,1339.45,113578,0.0000,1.0\r\n2021-05-19,1340.0,1357.45,1333.55,1336.55,1336.55,1047750,0.0000,1.0\r\n2021-05-18,1336.0,1344.45,1330.0,1339.95,1339.95,310214,0.0000,1.0\r\n2021-05-17,1319.7,1335.0,1319.7,1329.15,1329.15,287383,0.0000,1.0\r\n2021-05-14,1333.95,1333.95,1311.8,1316.8,1316.8,256247,0.0000,1.0\r\n2021-05-12,1332.0,1334.3,1315.0,1326.95,1326.95,1134464,0.0000,1.0\r\n2021-05-11,1336.0,1341.3,1325.25,1330.7,1330.7,305023,0.0000,1.0\r\n2021-0
# ...

# %%
rawData = pd.read_csv(io.StringIO(resp.content.decode('utf-8')))

# %%
rawData
# Out:
#        timestamp     open       high        low      close  adjusted_close  \
# 0     2021-05-28  1411.85  1414.0000  1396.3500  1404.8000       1404.8000
# 1     2021-05-27  1404.80  1415.5000  1391.6000  1404.6500       1404.6500
# 2     2021-05-26  1369.40  1400.0000  1362.0000  1397.3500       1397.3500
# 3     2021-05-25  1353.00  1367.5000  1353.0000  1361.9000       1361.9000
# 4     2021-05-24  1358.00  1362.1500  1345.2500  1348.1500       1348.1500
# ...          ...      ...        ...        ...        ...             ...
# 4034  2005-01-07  2040.00  2064.7008  1995.0496  2050.9008         94.6656
# 4035  2005-01-06  2055.00  2093.0000  1994.0000  2043.1504         94.3077
# 4036  2005-01-05  2078.00  2078.0000  2004.0000  2051.8496         94.7093
# 4037  2005-01-04  2120.00  2120.0000  2082.2496  2088.3504         96.3943
# 4038  2005-01-03  2099.00  2125.0000  2095.5008  2117.3504         97.7329
#
#         volume  dividend_amount  split_coefficient
# ...

# %% [markdown]
# # Yahoo

# %%
# !pip install pandas_datareader

# %%
from pandas_datareader import data as web

# %%
stock = 'INFY.NS'
 
df = web.DataReader(stock, data_source='yahoo', start='01-01-2015')

# %%
df
# Out:
#                    High          Low         Open        Close      Volume  \
# Date
# 2015-01-01   495.500000   489.225006   492.237488   493.600006   2002764.0
# 2015-01-02   504.762512   493.000000   493.000000   503.299988   6778320.0
# 2015-01-05   507.500000   494.375000   502.475006   498.975006   9937024.0
# 2015-01-06   496.250000   483.524994   495.000000   488.549988   9667316.0
# 2015-01-07   493.687500   487.500000   491.250000   490.887512   7249916.0
# ...                 ...          ...          ...          ...         ...
# 2021-05-24  1363.000000  1345.099976  1356.650024  1348.050049   4225371.0
# 2021-05-25  1368.000000  1354.449951  1358.000000  1361.599976   4099340.0
# 2021-05-26  1400.000000  1362.050049  1367.900024  1397.250000   6850024.0
# 2021-05-27  1416.250000  1391.699951  1404.199951  1402.250000  15365391.0
# 2021-05-28  1414.000000  1396.099976  1409.750000  1405.050049   4261312.0
#
#               Adj Close
# Date
# 2015-01-01   420.227753
# ...
