# %%
import pandas as pd
from pandas_datareader import data as web
import os
import numpy as np
from tqdm import tqdm

# %%
os.chdir("..")
from Technical_Indicators_master.indicator.indicators import EMA,RSI

# %%
with open('data/portfolio.txt','r') as f:
    portfolio = f.read().splitlines() 
    
portfolio = [x + '.NS' for x in portfolio]
len(portfolio)
# Out:
# 14

# %%
start_date_consider="01-01-2020"

# %%
all_results = []

for stock in tqdm(portfolio):
    
    df = web.DataReader(stock, data_source='yahoo', start=start_date_consider)
    df.reset_index(level=0, inplace=True)

    #metrics

    df = EMA(df, base = "Close", target = "EMA21", period = 21)
    df = EMA(df, base = "Close", target = "EMA7", period = 7)
    df = EMA(df, base = "Close", target = "EMA50", period = 50)
    df = RSI(df, base="Close", period=14)
    
    df2 = df.reindex(index=df.index[::-1])
    df2.reset_index(inplace = True)
    
    df2['difference_close'] = df2['Close'] - df2['Close'].shift(-1)
    df2['difference_EMA7'] = df2['EMA7'] - df2['EMA7'].shift(-1)
    
    results = {}
    results['stock'] = stock
    results['latest_date'] = df2.Date[0]
    results['last_close'] = np.round(df2.Close[0],2)
    results['current_lagdiff_close'] = np.round(df2.head(5).difference_close.values,2)
    results['current_lagdiff_EMA7'] = np.round(df2.head(5).difference_EMA7.values,2)
    results['RSIs'] = np.round(df2.head(5).RSI_14.values,2)
    results['ema_7_21'] = np.round(df2.head(5).EMA7 - df2.head(5).EMA21)
    results['ema_21_50'] = np.round(df2.head(5).EMA21 - df2.head(5).EMA50)
    
    #add to file
    all_results.append(results)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [00:14<00:00,  1.04s/it]

# %%
def print_report(list_of_dict):
    for results in list_of_dict:
        # further reports
        print("******************************************************\n")
        print("\t\t",results['stock'])
        print("Latest date in data = ",results['latest_date'])
        print("Last Close = ",results['last_close'])
        print("Latest diff values in EMA7 (recent first) = ",results['current_lagdiff_EMA7'])
        print("Latest RSI = ",results['RSIs'][0])

        if(any(results['RSIs']>78.0)):
            print("!! WARN !! RSI Value crossed 78, watch for sell")
        elif(any(results['RSIs']<22.0)):
            print("!!WARN !! RSI Value below, watchout for buy")

        if(any(results['ema_7_21']<0)):
            print("!! WARN !! EMA 7 is below EMA 21, watch for sell")
        else:
            print("EMA7 is above EMA21")

        if(any(results['ema_21_50']<0)):
            print("!! WARN !! EMA 21 is below EMA 50, fucking sell !!")
        else:
            print("EMA21 is above EMA50")
        print("\n")

# %%
print_report(all_results)
# Out:
# ******************************************************
#
# 		 ABB.NS
# Latest date in data =  2021-05-31 00:00:00
# Last Close =  1668.85
# Latest diff values in EMA7 (recent first) =  [38.01 23.98 28.8  12.44 14.68]
# Latest RSI =  84.05
# !! WARN !! RSI Value crossed 78, watch for sell
# EMA7 is above EMA21
# EMA21 is above EMA50
#
#
# ******************************************************
#
# 		 BEL.NS
# Latest date in data =  2021-05-31 00:00:00
# Last Close =  145.4
# Latest diff values in EMA7 (recent first) =  [-1.01 -1.53 -0.81 -0.68 -1.09]
# Latest RSI =  52.19
# EMA7 is above EMA21
# EMA21 is above EMA50
#
#
# ******************************************************
#
# 		 DLF.NS
# Latest date in data =  2021-05-31 00:00:00
# Last Close =  288.45
# Latest diff values in EMA7 (recent first) =  [2.22 2.24 2.02 5.3  3.  ]
# Latest RSI =  63.92
# EMA7 is above EMA21
# !! WARN !! EMA 21 is below EMA 50, fucking sell !!
#
#
# ******************************************************
#
# 		 DMART.NS
# Latest date in data =  2021-05-31 00:00:00
# Last Close =  3069.4
# Latest diff values in EMA7 (recent first) =  [ 8.94 -3.85 -4.   18.23 26.85]
# Latest RSI =  60.49
# EMA7 is above EMA21
# EMA21 is above EMA50
#
#
# ******************************************************
#
# 		 HCLTECH.NS
# Latest date in data =  2021-05-31 00:00:00
# Last Close =  945.2
# Latest diff values in EMA7 (recent first) =  [1.88 1.62 2.11 3.94 3.52]
# Latest RSI =  54.38
# !! WARN !! EMA 7 is below EMA 21, watch for sell
# !! WARN !! EMA 21 is below EMA 50, fucking sell !!
#
#
# ******************************************************
#
# 		 HDFCBANK.NS
# Latest date in data =  2021-05-31 00:00:00
# Last Close =  1515.85
# Latest diff values in EMA7 (recent first) =  [8.65 7.4  2.93 2.05 3.36]
# Latest RSI =  60.54
# EMA7 is above EMA21
# !! WARN !! EMA 21 is below EMA 50, fucking sell !!
#
#
# ******************************************************
#
# 		 INFY.NS
# Latest date in data =  2021-05-31 00:00:00
# Last Close =  1393.75
# Latest diff values in EMA7 (recent first) =  [ 3.67  8.66 10.61 12.48  4.76]
# Latest RSI =  61.16
# EMA7 is above EMA21
# EMA21 is above EMA50
#
#
# ******************************************************
#
# 		 ITC.NS
# Latest date in data =  2021-05-31 00:00:00
# Last Close =  216.6
# Latest diff values in EMA7 (recent first) =  [1.45 0.7  0.35 0.29 0.49]
# Latest RSI =  65.1
# EMA7 is above EMA21
# !! WARN !! EMA 21 is below EMA 50, fucking sell !!
#
#
# ******************************************************
#
# 		 LALPATHLAB.NS
# Latest date in data =  2021-05-31 00:00:00
# Last Close =  2956.15
# Latest diff values in EMA7 (recent first) =  [39.84  3.   -3.55 -2.98 -9.09]
# Latest RSI =  61.4
# !! WARN !! EMA 7 is below EMA 21, watch for sell
# EMA21 is above EMA50
#
#
# ******************************************************
#
# 		 M&M.NS
# Latest date in data =  2021-05-31 00:00:00
# Last Close =  807.95
# Latest diff values in EMA7 (recent first) =  [-2.85  8.84  6.04  5.58  4.13]
# Latest RSI =  52.89
# EMA7 is above EMA21
# !! WARN !! EMA 21 is below EMA 50, fucking sell !!
#
#
# ******************************************************
#
# 		 MARUTI.NS
# Latest date in data =  2021-05-31 00:00:00
# Last Close =  7086.3
# Latest diff values in EMA7 (recent first) =  [42.58 18.01 23.65 53.33 30.27]
# Latest RSI =  64.56
# EMA7 is above EMA21
# !! WARN !! EMA 21 is below EMA 50, fucking sell !!
#
#
# ******************************************************
#
# 		 SPICEJET.NS
# Latest date in data =  2021-05-31 00:00:00
# Last Close =  79.6
# Latest diff values in EMA7 (recent first) =  [0.3  0.26 0.16 1.   1.75]
# Latest RSI =  64.48
# EMA7 is above EMA21
# EMA21 is above EMA50
#
#
# ******************************************************
#
# 		 TATAMOTORS.NS
# Latest date in data =  2021-05-31 00:00:00
# Last Close =  318.75
# Latest diff values in EMA7 (recent first) =  [0.6  0.81 1.03 0.33 0.36]
# Latest RSI =  55.26
# EMA7 is above EMA21
# EMA21 is above EMA50
#
#
# ******************************************************
#
# 		 ZEEL.NS
# Latest date in data =  2021-05-31 00:00:00
# Last Close =  209.35
# Latest diff values in EMA7 (recent first) =  [1.5  2.8  3.07 2.82 2.3 ]
# Latest RSI =  65.04
# EMA7 is above EMA21
# !! WARN !! EMA 21 is below EMA 50, fucking sell !!
